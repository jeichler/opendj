# %% [markdown]
# # RHTE OpenDJ ML: Pre-analysis
# Goal: Analyse the options for a machine learning based curator.
#
# MVP: Organize playlist by grouping similar tracks
# 1. Determine groups in a list of given playlists using ML clustering (unsupervised learning)
# 2. Normalized data for prediction
# 3. Find supervised learning for predictions
# 4. Test prediction by building a playlist from random data

# %% [markdown]
# # Determine groups in a list of given playlist using ML clustering (unsupervised learning)
#
#
# - Read data
# - Show a few stats

# %%
import json
import numpy as np
import pandas as pd
import sklearn.utils
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.cluster import DBSCAN

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')


with open('data/all-tracks-input.json') as data_file:    
    input_data = json.load(data_file)

track_data = pd.DataFrame.from_dict(input_data, orient='columns')

# %% [markdown]
# ## Explore Data

# %%
print("\n** Shape:", track_data.shape)
print("\n** Columns:", track_data.columns)
# Out:
# ** Shape: (1223, 19)
#
# ** Columns: Index(['id', 'name', 'artist', 'year', 'image_url', 'duration_ms', 'preview',
#        'popularity', 'provider', 'genre', 'danceability', 'energy',
#        'acousticness', 'instrumentalness', 'liveness', 'happiness', 'bpm',
#        'genreSimple', 'genreSimpleNum'],
#       dtype='object')

# %%
print("\n** Some data:\n", track_data.head(5))
# Out:
# ** Some data:
#                         id                                       name  \
# 0  4m2RLN7imvsaLL1ZUGfFFw                             In White Rooms
# 1  2EQA1eRfXvbHKMjSnzUtFD                                         Go
# 2  3dX6WDwnHwYzB5t754oB4T                      Insomnia - Radio Edit
# 3  6l0LbTF2V77M3LPpcOBmqX                      Halcyon and On and On
# 4  1mv4lh1rW1K6xhxhJmEezy  Music Sounds Better With You - Radio Edit
#
#         artist  year                                          image_url  \
# 0  Booka Shade  2006  https://i.scdn.co/image/9266895a658d2f08c18a1d...
# 1         Moby  1992  https://i.scdn.co/image/5aeda4aa538ea0b0e5487b...
# 2    Faithless  2010  https://i.scdn.co/image/ec84ad08a54efb10642ce0...
# 3      Orbital  1993  https://i.scdn.co/image/9c2c32dfc5f2806c24c6f3...
# 4     Stardust  1998  https://i.scdn.co/image/69e94747e18634d1034dab...
#
#    duration_ms                                            preview  popularity  \
# 0       326840  https://p.scdn.co/mp3-preview/4534edc43f5c465b...          50
# 1       217000  https://p.scdn.co/mp3-preview/b61e35c58d285b8d...          45
# 2       215093  https://p.scdn.co/mp3-preview/a273663b695ada2a...          60
# 3       567106                                               None           5
# 4       260906  https://p.scdn.co/mp3-preview/90f925424294d179...          61
#
#   provider                                              genre  danceability  \
# 0  spotify  deep euro house, electronic, frankfurt electro...            80
# 1  spotify                              downtempo, electronic            68
# 2  spotify                    big beat, downtempo, electronic            72
# 3  spotify  alternative dance, big beat, breakbeat, drum a...            58
# 4  spotify                                                               73
#
#    energy  acousticness  instrumentalness  liveness  happiness  bpm  \
# 0      65             0                82        23         10  125
# 1      85             0                93         9         56  126
# 2      83             1                 1        10         28  127
# 3      73            10                93        18         18  127
# 4      66             0                21        31         36  124
#
#   genreSimple  genreSimpleNum
# 0       house              42
# 1   downtempo              15
# 2        beat               3
# 3       dance              12
# 4     unknown               1

# %%
track_data.head(5)
# Out:
#                        id                                       name  \
# 0  4m2RLN7imvsaLL1ZUGfFFw                             In White Rooms
# 1  2EQA1eRfXvbHKMjSnzUtFD                                         Go
# 2  3dX6WDwnHwYzB5t754oB4T                      Insomnia - Radio Edit
# 3  6l0LbTF2V77M3LPpcOBmqX                      Halcyon and On and On
# 4  1mv4lh1rW1K6xhxhJmEezy  Music Sounds Better With You - Radio Edit
#
#         artist  year                                          image_url  \
# 0  Booka Shade  2006  https://i.scdn.co/image/9266895a658d2f08c18a1d...
# 1         Moby  1992  https://i.scdn.co/image/5aeda4aa538ea0b0e5487b...
# 2    Faithless  2010  https://i.scdn.co/image/ec84ad08a54efb10642ce0...
# 3      Orbital  1993  https://i.scdn.co/image/9c2c32dfc5f2806c24c6f3...
# 4     Stardust  1998  https://i.scdn.co/image/69e94747e18634d1034dab...
#
#    duration_ms                                            preview  popularity  \
# 0       326840  https://p.scdn.co/mp3-preview/4534edc43f5c465b...          50
# 1       217000  https://p.scdn.co/mp3-preview/b61e35c58d285b8d...          45
# 2       215093  https://p.scdn.co/mp3-preview/a273663b695ada2a...          60
# 3       567106                                               None           5
# 4       260906  https://p.scdn.co/mp3-preview/90f925424294d179...          61
#
#   provider                                              genre  danceability  \
# 0  spotify  deep euro house, electronic, frankfurt electro...            80
# 1  spotify                              downtempo, electronic            68
# 2  spotify                    big beat, downtempo, electronic            72
# 3  spotify  alternative dance, big beat, breakbeat, drum a...            58
# 4  spotify                                                               73
#
#    energy  acousticness  instrumentalness  liveness  happiness  bpm  \
# 0      65             0                82        23         10  125
# 1      85             0                93         9         56  126
# 2      83             1                 1        10         28  127
# 3      73            10                93        18         18  127
# 4      66             0                21        31         36  124
#
#   genreSimple  genreSimpleNum
# 0       house              42
# 1   downtempo              15
# 2        beat               3
# 3       dance              12
# 4     unknown               1

# %%
print("\n** Info:\n", track_data.info)
# Out:
# ** Info:
#  <bound method DataFrame.info of                           id                                       name  \
# 0     4m2RLN7imvsaLL1ZUGfFFw                             In White Rooms
# 1     2EQA1eRfXvbHKMjSnzUtFD                                         Go
# 2     3dX6WDwnHwYzB5t754oB4T                      Insomnia - Radio Edit
# 3     6l0LbTF2V77M3LPpcOBmqX                      Halcyon and On and On
# 4     1mv4lh1rW1K6xhxhJmEezy  Music Sounds Better With You - Radio Edit
# ...                      ...                                        ...
# 1218  3SmULHya2wcmiJghjWTL4P                                 Белладонна
# 1219  1oh902Dm2qtg6TiTpcdCdH                            Ты меня пленила
# 1220  77H5pHxR5WBUHQuNo5fb5N                                      Аллея
# 1221  6btAjUGgNab1Pk52sQRMzu                              Пустой стакан
# 1222  20XStJJIHddGpddVTYXxSq                                     Звезда
#
#                artist  year  \
# 0         Booka Shade  2006
# 1                Moby  1992
# 2           Faithless  2010
# 3             Orbital  1993
# 4            Stardust  1998
# ...               ...   ...
# 1218  Dzharo & Khanza  2018
# 1219             Jony  2019
# 1220             Jony  2019
# 1221             Jony  2019
# 1222             Jony  2019
#
#                                               image_url  duration_ms  \
# 0     https://i.scdn.co/image/9266895a658d2f08c18a1d...       326840
# 1     https://i.scdn.co/image/5aeda4aa538ea0b0e5487b...       217000
# 2     https://i.scdn.co/image/ec84ad08a54efb10642ce0...       215093
# 3     https://i.scdn.co/image/9c2c32dfc5f2806c24c6f3...       567106
# 4     https://i.scdn.co/image/69e94747e18634d1034dab...       260906
# ...                                                 ...          ...
# 1218  https://i.scdn.co/image/081c905d6f8889c5e1e124...       189500
# 1219  https://i.scdn.co/image/37b194ae731021f28460a7...       192000
# 1220  https://i.scdn.co/image/37b194ae731021f28460a7...       142670
# 1221  https://i.scdn.co/image/37b194ae731021f28460a7...       193613
# 1222  https://i.scdn.co/image/37b194ae731021f28460a7...       160481
#
#                                                 preview  popularity provider  \
# 0     https://p.scdn.co/mp3-preview/4534edc43f5c465b...          50  spotify
# 1     https://p.scdn.co/mp3-preview/b61e35c58d285b8d...          45  spotify
# 2     https://p.scdn.co/mp3-preview/a273663b695ada2a...          60  spotify
# 3                                                  None           5  spotify
# 4     https://p.scdn.co/mp3-preview/90f925424294d179...          61  spotify
# ...                                                 ...         ...      ...
# 1218  https://p.scdn.co/mp3-preview/ae357dfd7993cb22...          28  spotify
# 1219  https://p.scdn.co/mp3-preview/e397b3c00f9b600c...          49  spotify
# 1220  https://p.scdn.co/mp3-preview/e6fea1cb72d1c8fa...          51  spotify
# 1221  https://p.scdn.co/mp3-preview/beadd844431c4c69...          44  spotify
# 1222  https://p.scdn.co/mp3-preview/60372532210d5077...          46  spotify
#
#                                                   genre  danceability  energy  \
# 0     deep euro house, electronic, frankfurt electro...            80      65
# 1                                 downtempo, electronic            68      85
# 2                       big beat, downtempo, electronic            72      83
# 3     alternative dance, big beat, breakbeat, drum a...            58      73
# 4                                                                  73      66
# ...                                                 ...           ...     ...
# 1218                                    russian hip hop            71      58
# 1219                     russian dance, russian hip hop            35      83
# 1220                     russian dance, russian hip hop            48      54
# 1221                     russian dance, russian hip hop            88      69
# 1222                     russian dance, russian hip hop            41      71
#
#       acousticness  instrumentalness  liveness  happiness  bpm genreSimple  \
# 0                0                82        23         10  125       house
# 1                0                93         9         56  126   downtempo
# 2                1                 1        10         28  127        beat
# 3               10                93        18         18  127       dance
# 4                0                21        31         36  124     unknown
# ...            ...               ...       ...        ...  ...         ...
# 1218            19                 0        24         68   77     hip hop
# 1219            82                 0        10         13  119       dance
# 1220            65                 0        20         23  176       dance
# 1221            34                 0         7         59  119       dance
# 1222            88                 0        11         18  166       dance
#
#       genreSimpleNum
# 0                 42
# 1                 15
# 2                  3
# 3                 12
# 4                  1
# ...              ...
# 1218              41
# 1219              12
# 1220              12
# 1221              12
# 1222              12
#
# [1223 rows x 19 columns]>

# %%
print("\n** Stats:\n", track_data.describe)
# Out:
# ** Stats:
#  <bound method NDFrame.describe of                           id                                       name  \
# 0     4m2RLN7imvsaLL1ZUGfFFw                             In White Rooms
# 1     2EQA1eRfXvbHKMjSnzUtFD                                         Go
# 2     3dX6WDwnHwYzB5t754oB4T                      Insomnia - Radio Edit
# 3     6l0LbTF2V77M3LPpcOBmqX                      Halcyon and On and On
# 4     1mv4lh1rW1K6xhxhJmEezy  Music Sounds Better With You - Radio Edit
# ...                      ...                                        ...
# 1218  3SmULHya2wcmiJghjWTL4P                                 Белладонна
# 1219  1oh902Dm2qtg6TiTpcdCdH                            Ты меня пленила
# 1220  77H5pHxR5WBUHQuNo5fb5N                                      Аллея
# 1221  6btAjUGgNab1Pk52sQRMzu                              Пустой стакан
# 1222  20XStJJIHddGpddVTYXxSq                                     Звезда
#
#                artist  year  \
# 0         Booka Shade  2006
# 1                Moby  1992
# 2           Faithless  2010
# 3             Orbital  1993
# 4            Stardust  1998
# ...               ...   ...
# 1218  Dzharo & Khanza  2018
# 1219             Jony  2019
# 1220             Jony  2019
# 1221             Jony  2019
# 1222             Jony  2019
#
#                                               image_url  duration_ms  \
# 0     https://i.scdn.co/image/9266895a658d2f08c18a1d...       326840
# 1     https://i.scdn.co/image/5aeda4aa538ea0b0e5487b...       217000
# 2     https://i.scdn.co/image/ec84ad08a54efb10642ce0...       215093
# 3     https://i.scdn.co/image/9c2c32dfc5f2806c24c6f3...       567106
# 4     https://i.scdn.co/image/69e94747e18634d1034dab...       260906
# ...                                                 ...          ...
# 1218  https://i.scdn.co/image/081c905d6f8889c5e1e124...       189500
# 1219  https://i.scdn.co/image/37b194ae731021f28460a7...       192000
# 1220  https://i.scdn.co/image/37b194ae731021f28460a7...       142670
# 1221  https://i.scdn.co/image/37b194ae731021f28460a7...       193613
# 1222  https://i.scdn.co/image/37b194ae731021f28460a7...       160481
#
#                                                 preview  popularity provider  \
# 0     https://p.scdn.co/mp3-preview/4534edc43f5c465b...          50  spotify
# 1     https://p.scdn.co/mp3-preview/b61e35c58d285b8d...          45  spotify
# 2     https://p.scdn.co/mp3-preview/a273663b695ada2a...          60  spotify
# 3                                                  None           5  spotify
# 4     https://p.scdn.co/mp3-preview/90f925424294d179...          61  spotify
# ...                                                 ...         ...      ...
# 1218  https://p.scdn.co/mp3-preview/ae357dfd7993cb22...          28  spotify
# 1219  https://p.scdn.co/mp3-preview/e397b3c00f9b600c...          49  spotify
# 1220  https://p.scdn.co/mp3-preview/e6fea1cb72d1c8fa...          51  spotify
# 1221  https://p.scdn.co/mp3-preview/beadd844431c4c69...          44  spotify
# 1222  https://p.scdn.co/mp3-preview/60372532210d5077...          46  spotify
#
#                                                   genre  danceability  energy  \
# 0     deep euro house, electronic, frankfurt electro...            80      65
# 1                                 downtempo, electronic            68      85
# 2                       big beat, downtempo, electronic            72      83
# 3     alternative dance, big beat, breakbeat, drum a...            58      73
# 4                                                                  73      66
# ...                                                 ...           ...     ...
# 1218                                    russian hip hop            71      58
# 1219                     russian dance, russian hip hop            35      83
# 1220                     russian dance, russian hip hop            48      54
# 1221                     russian dance, russian hip hop            88      69
# 1222                     russian dance, russian hip hop            41      71
#
#       acousticness  instrumentalness  liveness  happiness  bpm genreSimple  \
# 0                0                82        23         10  125       house
# 1                0                93         9         56  126   downtempo
# 2                1                 1        10         28  127        beat
# 3               10                93        18         18  127       dance
# 4                0                21        31         36  124     unknown
# ...            ...               ...       ...        ...  ...         ...
# 1218            19                 0        24         68   77     hip hop
# 1219            82                 0        10         13  119       dance
# 1220            65                 0        20         23  176       dance
# 1221            34                 0         7         59  119       dance
# 1222            88                 0        11         18  166       dance
#
#       genreSimpleNum
# 0                 42
# 1                 15
# 2                  3
# 3                 12
# 4                  1
# ...              ...
# 1218              41
# 1219              12
# 1220              12
# 1221              12
# 1222              12
#
# [1223 rows x 19 columns]>

# %% [markdown]
# ## Cluster Data
# ### Prep data
# - One hot encoding of genresimple
# - Convert years to decade
# - danceability to bool

# %%
title = "Clustering with genresimple, year as 'scalced' decade and danceability"

print("**** ", title)

genresimple_onehot = pd.get_dummies(track_data['genreSimple'], prefix = 'genresimple')

# Create decade with 1900 decade as zero
y=track_data['year'].values
scaled_decades = np.array(((y - 1900) - (y - 1900) % 10) / 100)

# Prep danceability bool
d=track_data['danceability'].values
dance = np.array(d > 50)
# Out:
# ****  Clustering with genresimple, year as 'scalced' decade and danceability

# %% [markdown]
# ### Cluster data
# - Prep / join features
# - Perform clustering
# - Save results
# - Plot distribution

# %%
# Join data
track_data_features = np.column_stack((scaled_decades, dance, genresimple_onehot.to_numpy()))
db = DBSCAN(algorithm='auto', eps=0.1, min_samples=3 ).fit(track_data_features)

labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)

print('** Number of clusters: %d' % n_clusters_)

unique, counts = np.unique(labels, return_counts=True)
distribution = dict(zip(unique, counts))

print("** Distribution:", distribution)

track_data_cluster = pd.concat([track_data, pd.DataFrame(labels,columns=['cluster'])], axis=1)
track_data_cluster.to_csv('data/all-tracks-clusters-raw.csv', index=False, encoding='utf-8')


x_pos = [i for i, _ in enumerate(unique)]

width_in_inches = 12
height_in_inches = 4
dots_per_inch = 100

plt.figure(
    figsize=(width_in_inches, height_in_inches),
    dpi=dots_per_inch)

plt.bar(x_pos, counts, color='green')
plt.xlabel("Cluster found (-1 = noise)")
plt.ylabel("Number of tracks in cluster")
plt.title(title)
plt.xticks(x_pos, unique)
plt.show()
# Out:
# ** Number of clusters: 60
# ** Distribution: {-1: 74, 0: 16, 1: 4, 2: 36, 3: 22, 4: 3, 5: 35, 6: 8, 7: 3, 8: 22, 9: 4, 10: 4, 11: 17, 12: 86, 13: 5, 14: 45, 15: 10, 16: 6, 17: 4, 18: 3, 19: 100, 20: 8, 21: 44, 22: 20, 23: 3, 24: 3, 25: 26, 26: 11, 27: 6, 28: 19, 29: 4, 30: 24, 31: 25, 32: 139, 33: 66, 34: 13, 35: 4, 36: 10, 37: 11, 38: 4, 39: 3, 40: 10, 41: 4, 42: 52, 43: 70, 44: 4, 45: 52, 46: 5, 47: 9, 48: 4, 49: 5, 50: 5, 51: 9, 52: 8, 53: 4, 54: 12, 55: 7, 56: 4, 57: 3, 58: 3, 59: 3}

# %% [markdown]
# ### Normalize / de-skew data
# - Trim down cluster with more than 50 items
# - Plot data
# - Save data

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# Trim down cluster with more than 50 items
df = pd.DataFrame( track_data_cluster['cluster'].value_counts())
for a in df[df.cluster > 50].index:
    # print(a)
    dfx = track_data_cluster[track_data_cluster.cluster == a ]
    dfx = shuffle(dfx)
    train, test = train_test_split(dfx, test_size= 50 / dfx.shape[0])
    track_data_cluster = track_data_cluster.drop(track_data_cluster[track_data_cluster.cluster == a].index)
    track_data_cluster = track_data_cluster.append(test)

# Plot data
title = "De-Skewed data ...."

plt.figure(
    figsize=(width_in_inches, height_in_inches),
    dpi=dots_per_inch)

plt.bar(x_pos, track_data_cluster['cluster'].value_counts().sort_index().values, color='green')
plt.xlabel("Clusters found (-1 = noise)")
plt.ylabel("Number of tracks in cluster")
plt.title(title)
plt.xticks(x_pos, track_data_cluster['cluster'].value_counts().sort_index().index)
plt.show()

# Drop Unknown and save to file
track_data_cluster = track_data_cluster.drop(track_data_cluster[track_data_cluster.cluster == -1].index)
track_data_cluster.to_csv('data/all-tracks-clusters-clean.csv', index=False, encoding='utf-8')

# %% [markdown]
# # Find supervized learning for predictions
# - Load clustered data from disk
# - Feature engineering
# - Train various models
#
# ## Load clustered data from disk and Feature engineering

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.utils.validation import column_or_1d

from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.multiclass import OutputCodeClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import f1_score
import pickle
import random


prefix_genresimple = 'genresimple'

input_data = pd.read_csv('data/all-tracks-clusters-clean.csv') 

print ("== Load data ", "="*40)  
print ("The dataset has {} data points with {} variables each.".format(*input_data.shape)) 
print (input_data.columns)

#################################################
# Shortcut: Prepare data like it was use for clustering

track_data = input_data[['genreSimple', 'year','danceability', 'cluster']]

# One hot encoding of genreSimple
genresimple_onehot = pd.get_dummies(track_data['genreSimple'], prefix = prefix_genresimple)

# One hot encoding of the cluster

#clusterid_onehot = pd.get_dummies(track_data['cluster'], prefix = 'cluster')

# Create decade with 1900 decade as zero
y=track_data['year'].values
scaled_decades = np.array(((y - 1900) - (y - 1900) % 10) / 100)

# Prep danceability bool
dance = np.array(track_data['danceability'].values > 50)

# Merge features into data frame
track_data_features = pd.concat([pd.DataFrame(dance, columns=['danceability']), pd.DataFrame(scaled_decades, columns=['decade']), genresimple_onehot], axis=1)

print ("== Features ", "="*40)  
print ("The feature dataset has {} data points with {} variables each.".format(*track_data_features.shape)) 
print (track_data_features.columns)
# Out:
# == Load data  ========================================
# The dataset has 934 data points with 20 variables each.
# Index(['id', 'name', 'artist', 'year', 'image_url', 'duration_ms', 'preview',
#        'popularity', 'provider', 'genre', 'danceability', 'energy',
#        'acousticness', 'instrumentalness', 'liveness', 'happiness', 'bpm',
#        'genreSimple', 'genreSimpleNum', 'cluster'],
#       dtype='object')
# == Features  ========================================
# The feature dataset has 934 data points with 29 variables each.
# Index(['danceability', 'decade', 'genresimple_beat', 'genresimple_boy band',
#        'genresimple_dance', 'genresimple_disco', 'genresimple_edm',
#        'genresimple_electro', 'genresimple_electronic',
#        'genresimple_electropop', 'genresimple_eurodance',
#        'genresimple_europop', 'genresimple_folk', 'genresimple_funk',
#        'genresimple_hip hop', 'genresimple_house', 'genresimple_indie',
#        'genresimple_invasion', 'genresimple_latin', 'genresimple_metal',
#        'genresimple_pop', 'genresimple_punk', 'genresimple_rock',
#        'genresimple_room', 'genresimple_soul', 'genresimple_techno',
#        'genresimple_trance', 'genresimple_unknown', 'genresimple_wave'],
#       dtype='object')

# %% [markdown]
# ## Train various models

# %%
# Train models. Create test and training  data 
# print ("The feature dataset has {} data points with {} variables each.".format(*track_data_features.shape)) 
print (track_data_features.columns)

pct_test_size = 0.2
my_random_seed = 69

# X_all = track_data_features.values
# y_all = clusterid_onehot.values

clusterid_onehot = input_data[['cluster']]

print ("* Feature shape:", track_data_features.shape)
print ("* Labels shape:", clusterid_onehot.shape)


X_train, X_test, y_train, y_test  = train_test_split(track_data_features, clusterid_onehot, stratify=clusterid_onehot, test_size=pct_test_size, random_state=my_random_seed)

#
# Helper Functions to train and predicit 
#
 
def predict_labels(clf, features, target):
    ''' Makes predictions using a fit classifier based on F1 score. '''
    
    y_pred = clf.predict(features)
 
    # Print and return results
    #return f1_score(target.values, y_pred, pos_label='yes', average='micro')
    return f1_score(target.values, y_pred, average='micro')

def train_predict(clf, X_train, y_train, X_test, y_test):
    ''' Train and predict using a classifer based on F1 score. '''
    
    # Indicate the classifier and the training set size
    print ("Training a {} using a training set size of {}. . .".format(clf.__class__.__name__, len(X_train)))
    
    # Train the classifier

    clf.fit(X_train, column_or_1d(y_train))
    
    # Print the results of prediction for both training and testing
    print ("F1 score for training set: {:.4f}.".format(predict_labels(clf, X_train, y_train)))
    print ("F1 score for test set: {:.4f}.".format(predict_labels(clf, X_test, y_test)))
    
    
    
#  Initialize the three models
clf_A = DecisionTreeClassifier(random_state=my_random_seed)
clf_B = SVC(gamma='auto', random_state=my_random_seed)
clf_C = LinearSVC()
clf_D = OutputCodeClassifier(LinearSVC(random_state=0), code_size=2, random_state=my_random_seed)


# loop thru models [clf_A, clf_B, clf_B, clf_D]
for clf in [clf_A, clf_B, clf_C, clf_D]:
    print ("\n{}: \n".format(clf.__class__.__name__))
    train_predict(clf, X_train, y_train, X_test, y_test)
    scores = cross_val_score(clf, track_data_features, column_or_1d(clusterid_onehot), cv=3)
    print ("cross_validation:", scores, scores.mean())


#
# TODO: Tuning the hyper-parameters of the estimator. Skip for now. 
#
    
#
# Save model to disk  
#    

print ("\n","="*60)  
print ("* Save {} model".format(clf_A.__class__.__name__))
 
# save the model to disk
filename = 'data/finalized_model.sav'
pickle.dump(clf_A, open(filename, 'wb'))
# Out:
# Index(['danceability', 'decade', 'genresimple_beat', 'genresimple_boy band',
#        'genresimple_dance', 'genresimple_disco', 'genresimple_edm',
#        'genresimple_electro', 'genresimple_electronic',
#        'genresimple_electropop', 'genresimple_eurodance',
#        'genresimple_europop', 'genresimple_folk', 'genresimple_funk',
#        'genresimple_hip hop', 'genresimple_house', 'genresimple_indie',
#        'genresimple_invasion', 'genresimple_latin', 'genresimple_metal',
#        'genresimple_pop', 'genresimple_punk', 'genresimple_rock',
#        'genresimple_room', 'genresimple_soul', 'genresimple_techno',
#        'genresimple_trance', 'genresimple_unknown', 'genresimple_wave'],
#       dtype='object')
# * Feature shape: (934, 29)
# * Labels shape: (934, 1)
#
# DecisionTreeClassifier:
#
# Training a DecisionTreeClassifier using a training set size of 747. . .
# F1 score for training set: 1.0000.
# F1 score for test set: 1.0000.
# cross_validation: [1. 1. 1.] 1.0
#
# SVC:
#
# Training a SVC using a training set size of 747. . .
# F1 score for training set: 0.6051.
# F1 score for test set: 0.5989.
# cross_validation: [0.57057057 0.59807074 0.6137931 ] 0.5941448045228953
#
# LinearSVC:
#
# Training a LinearSVC using a training set size of 747. . .
# F1 score for training set: 0.7510.
# F1 score for test set: 0.7433.
# cross_validation: [0.78078078 0.74276527 0.74827586] 0.7572739720538811
#
# OutputCodeClassifier:
#
# Training a OutputCodeClassifier using a training set size of 747. . .
# F1 score for training set: 0.6305.
# F1 score for test set: 0.6096.
# cross_validation: [0.60660661 0.62700965 0.64482759] 0.6261479463719181
#
#  ============================================================
# * Save DecisionTreeClassifier model

# %% [markdown]
# ### Load model and check F1 score

# %%
# load the model from disk

print ("* Local saved model and score again ...")


loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.predict(X_test)

print ("{}: F1 score for test set: {:.4f}.".format(clf_A.__class__.__name__, f1_score(y_test.values, result, average='micro')))
# Out:
# * Local saved model and score again ...
# DecisionTreeClassifier: F1 score for test set: 1.0000.

# %% [markdown]
# # Test: Build a playlist from random data

# %%
#
# Few Tests: 1. Build a playlist from random data
#

def predict_cluster(track: dict):
    ''' Predict a clsuter id for a given track. Pass track as dict. '''
    
    cluster_id = -1
    
    track_genresimple_onehot = dict(zip( genresimple_onehot.columns, [0] * len(list(genresimple_onehot.columns)) ))
    track_genresimple_onehot[prefix_genresimple +   '_' +  test_track['genreSimple']] = 1

    y = track['year']

    t = [ track['danceability'] > 50, ((y - 1900) - (y - 1900) % 10) / 100 ]
    t.extend(list(track_genresimple_onehot.values()))
    cluster_id = loaded_model.predict([t])[0]
    return cluster_id


def insert_row(row_nr, df, row): 
    df1 = df[0:row_nr] 
    df2 = df[row_nr:]  
    #df1.loc[row_nr]=row  
   
    df1 = df1.append(row)
    df_result = pd.concat([df1, df2]) 
    df_result.index = [*range(df_result.shape[0])] 
    return df_result 

play_list = pd.DataFrame(columns=input_data.columns)

for i in range(100):
    j = random.randint(0, input_data.shape[0]-1)
    test_track = input_data.iloc[j, :].to_dict()  
    predicted_cluster_id = predict_cluster(test_track)

    print("{}/{}: Artist: {}, Genre: {}, Year: {}, Dance: {} => {}".format( i,j, \
          test_track['artist'],test_track['genreSimple'],test_track['year'],test_track['danceability'],predicted_cluster_id ))

    cluster_pos = list(play_list.loc[play_list['cluster'] == predicted_cluster_id].index)

    if len(cluster_pos) == 0:
        play_list = play_list.append(input_data.iloc[j, :])
    else:
        play_list = insert_row(cluster_pos[-1], play_list, input_data.iloc[j, :])
        
        print ("Insert:", j)
    play_list.index = [*range(play_list.shape[0])]
# Out:
# 0/107: Artist: Mia., Genre: indie, Year: 2004, Dance: 72 => 27
# 1/580: Artist: Jony, Genre: dance, Year: 2019, Dance: 35 => 13
# 2/201: Artist: Eddie Thoneick, Genre: room, Year: 2019, Dance: 63 => 21
# 3/103: Artist: Mia., Genre: indie, Year: 2006, Dance: 75 => 27
# Insert: 103
# 4/794: Artist: Pink Floyd, Genre: rock, Year: 2001, Dance: 50 => 33
# 5/28: Artist: Sylvia Tosun, Genre: trance, Year: 2008, Dance: 70 => 16
# 6/317: Artist: Will Smith, Genre: hip hop, Year: 1997, Dance: 88 => 28
# 7/531: Artist: Gemini Syndrome, Genre: unknown, Year: 2016, Dance: 50 => 20
# 8/345: Artist: Yeah Yeah Yeahs, Genre: dance, Year: 2009, Dance: 56 => 2
# 9/147: Artist: Modjo, Genre: house, Year: 2013, Dance: 73 => 14
# 10/429: Artist: Sister Sledge, Genre: pop, Year: 1979, Dance: 76 => 37
# 11/809: Artist: Radiohead, Genre: rock, Year: 1995, Dance: 42 => 33
# Insert: 809
# 12/861: Artist: Jane's Addiction, Genre: metal, Year: 1988, Dance: 32 => 45
# 13/640: Artist: Sean Paul, Genre: pop, Year: 2017, Dance: 91 => 19
# 14/536: Artist: Amy Lee, Genre: unknown, Year: 2017, Dance: 50 => 20
# Insert: 536
# 15/617: Artist: Billy Idol, Genre: rock, Year: 1983, Dance: 54 => 32
# 16/147: Artist: Modjo, Genre: house, Year: 2013, Dance: 73 => 14
# Insert: 147
# 17/862: Artist: Soundgarden, Genre: metal, Year: 1994, Dance: 27 => 45
# Insert: 862
# 18/525: Artist: Through Fire, Genre: unknown, Year: 2016, Dance: 48 => 20
# Insert: 525
# 19/358: Artist: Gnarls Barkley, Genre: hip hop, Year: 2006, Dance: 86 => 28
# Insert: 358
# 20/434: Artist: Isaac Hayes, Genre: soul, Year: 1971, Dance: 50 => 55
# 21/888: Artist: Led Zeppelin, Genre: rock, Year: 1971, Dance: 35 => 42
# 22/635: Artist: Imany, Filatov & Karas, Genre: pop, Year: 2015, Dance: 74 => 19
# Insert: 635
# 23/701: Artist: Mark Ronson, Amy Winehouse, Genre: pop, Year: 2007, Dance: 70 => 12
# 24/94: Artist: Juju, Genre: hip hop, Year: 2019, Dance: 77 => 25
# 25/472: Artist: Eddie Money, Genre: rock, Year: 2014, Dance: 59 => 30
# 26/93: Artist: Calvin Harris, Rag'n'Bone Man, Genre: edm, Year: 2019, Dance: 81 => 11
# 27/181: Artist: Hanson, Genre: boy band, Year: 2008, Dance: 69 => 38
# 28/426: Artist: Donny Hathaway, Genre: soul, Year: 1970, Dance: 74 => 47
# 29/266: Artist: Kaskade, Madge, Genre: room, Year: 2019, Dance: 88 => 21
# Insert: 266
# 30/221: Artist: Kideko, Genre: house, Year: 2019, Dance: 60 => 14
# Insert: 221
# 31/617: Artist: Billy Idol, Genre: rock, Year: 1983, Dance: 54 => 32
# Insert: 617
# 32/275: Artist: Fatboy Slim, Genre: beat, Year: 2006, Dance: 62 => 15
# 33/197: Artist: Leandro Da Silva, Genre: house, Year: 2018, Dance: 66 => 14
# Insert: 197
# 34/393: Artist: Collective Soul, Genre: metal, Year: 1994, Dance: 54 => 31
# 35/115: Artist: Alle Farben, Graham Candy, Genre: house, Year: 2014, Dance: 83 => 14
# Insert: 115
# 36/120: Artist: Guano Apes, Ronald Prent at Wisselord Studios, Hilversum, Netherland, Genre: metal, Year: 1997, Dance: 66 => 31
# Insert: 120
# 37/375: Artist: James Brown, Genre: funk, Year: 1991, Dance: 88 => 48
# 38/136: Artist: Moloko, Boris Dlugosch, Michael Lange, Genre: dance, Year: 2006, Dance: 76 => 2
# Insert: 136
# 39/338: Artist: Korn, Genre: metal, Year: 2004, Dance: 57 => 31
# Insert: 338
# 40/759: Artist: The Sonics, Genre: rock, Year: 1965, Dance: 51 => 43
# 41/708: Artist: Justin Timberlake, Genre: pop, Year: 2006, Dance: 86 => 12
# Insert: 708
# 42/553: Artist: Kevin Lyttle, Genre: unknown, Year: 2004, Dance: 68 => 3
# 43/403: Artist: Incubus, Genre: metal, Year: 1999, Dance: 58 => 31
# Insert: 403
# 44/21: Artist: The Chemical Brothers, Genre: dance, Year: 2010, Dance: 49 => 13
# Insert: 21
# 45/351: Artist: Ace of Base, Genre: dance, Year: 1992, Dance: 80 => 2
# Insert: 351
# 46/297: Artist: A Touch Of Class, Pete Konemann, Genre: dance, Year: 2000, Dance: 62 => 2
# Insert: 297
# 47/243: Artist: Deniz Koyu, Genre: room, Year: 2019, Dance: 57 => 21
# Insert: 243
# 48/869: Artist: Alice In Chains, Genre: metal, Year: 1990, Dance: 35 => 45
# Insert: 869
# 49/608: Artist: The Raconteurs, Genre: rock, Year: 2006, Dance: 53 => 32
# Insert: 608
# 50/171: Artist: Toto, Genre: rock, Year: 2013, Dance: 69 => 30
# Insert: 171
# 51/223: Artist: Damien N-Drix, STV, Genre: house, Year: 2017, Dance: 76 => 14
# Insert: 223
# 52/454: Artist: Donny Hathaway, Genre: soul, Year: 1971, Dance: 32 => 55
# Insert: 454
# 53/763: Artist: Deep Purple, Genre: rock, Year: 1972, Dance: 60 => 43
# Insert: 763
# 54/921: Artist: Patti Smith, Genre: rock, Year: 1978, Dance: 47 => 42
# Insert: 921
# 55/35: Artist: Tiësto, Genre: room, Year: 2009, Dance: 60 => 8
# 56/513: Artist: Kyras, Valeria Rossi, Genre: unknown, Year: 2016, Dance: 72 => 5
# 57/179: Artist: Agnes, Genre: electropop, Year: 2005, Dance: 69 => 18
# 58/46: Artist: Eric Prydz, Genre: room, Year: 2004, Dance: 60 => 8
# Insert: 46
# 59/839: Artist: Foo Fighters, Genre: metal, Year: 1997, Dance: 41 => 45
# Insert: 839
# 60/487: Artist: The Beatles, Genre: invasion, Year: 1965, Dance: 33 => 59
# 61/132: Artist: Mr. Oizo, Genre: house, Year: 1999, Dance: 94 => 0
# 62/388: Artist: Nine Inch Nails, Genre: metal, Year: 1989, Dance: 67 => 31
# Insert: 388
# 63/558: Artist: fun., Janelle Monáe, Genre: pop, Year: 2012, Dance: 38 => 50
# 64/615: Artist: Alanis Morissette, Genre: rock, Year: 1995, Dance: 66 => 32
# Insert: 615
# 65/520: Artist: As Lions, Genre: unknown, Year: 2017, Dance: 20 => 20
# Insert: 520
# 66/232: Artist: CamelPhat, Genre: house, Year: 2017, Dance: 64 => 14
# Insert: 232
# 67/318: Artist: Duck Sauce, Genre: house, Year: 2010, Dance: 77 => 14
# Insert: 318
# 68/725: Artist: Ciara, Justin Timberlake, Genre: pop, Year: 2009, Dance: 90 => 12
# Insert: 725
# 69/9: Artist: Everything But The Girl, Todd Terry, Genre: electronic, Year: 1994, Dance: 72 => 7
# 70/183: Artist: Daddy's Groove, Genre: room, Year: 2018, Dance: 73 => 21
# Insert: 183
# 71/181: Artist: Hanson, Genre: boy band, Year: 2008, Dance: 69 => 38
# Insert: 181
# 72/260: Artist: Tiësto, Dzeko, Lena Leon, Genre: room, Year: 2019, Dance: 59 => 21
# Insert: 260
# 73/605: Artist: Fugazi, Genre: rock, Year: 1989, Dance: 62 => 32
# Insert: 605
# 74/772: Artist: Jimi Hendrix, Genre: rock, Year: 1967, Dance: 53 => 43
# Insert: 772
# 75/856: Artist: Guns N' Roses, Genre: metal, Year: 1987, Dance: 45 => 45
# Insert: 856
# 76/639: Artist: HammAli & Navai, Genre: pop, Year: 2018, Dance: 81 => 19
# Insert: 639
# 77/507: Artist: Lost Frequencies, Genre: edm, Year: 2014, Dance: 78 => 11
# Insert: 507
# 78/766: Artist: Lou Reed, Genre: rock, Year: 1972, Dance: 57 => 43
# Insert: 766
# 79/693: Artist: Katrina & The Waves, Genre: pop, Year: 1985, Dance: 60 => 12
# Insert: 693
# 80/586: Artist: Bill Medley, Jennifer Warnes, Genre: rock, Year: 1987, Dance: 70 => 32
# Insert: 586
# 81/68: Artist: DJ Mog Feat Sarah Lynn, Genre: unknown, Year: 2010, Dance: 42 => 20
# Insert: 68
# 82/681: Artist: Lauv, Troye Sivan, Genre: pop, Year: 2019, Dance: 60 => 19
# Insert: 681
# 83/769: Artist: Kraftwerk, Genre: rock, Year: 1978, Dance: 71 => 43
# Insert: 769
# 84/544: Artist: *NSYNC, Genre: boy band, Year: 2000, Dance: 61 => 38
# Insert: 544
# 85/902: Artist: Rainbow, Genre: rock, Year: 1976, Dance: 38 => 42
# Insert: 902
# 86/530: Artist: Shaman's Harvest, Genre: metal, Year: 2014, Dance: 46 => 54
# 87/446: Artist: Toto, Genre: rock, Year: 2014, Dance: 48 => 26
# 88/406: Artist: Green Day, Genre: wave, Year: 1994, Dance: 37 => 52
# 89/576: Artist: Feduk, Genre: hip hop, Year: 2017, Dance: 86 => 25
# Insert: 576
# 90/182: Artist: Pato's Groove, Joe Manina, Antonio Manero Spaziani, Genre: unknown, Year: 2018, Dance: 55 => 5
# Insert: 182
# 91/768: Artist: The Rolling Stones, Genre: rock, Year: 1965, Dance: 73 => 43
# Insert: 768
# 92/211: Artist: FISHER, Genre: house, Year: 2019, Dance: 93 => 14
# Insert: 211
# 93/298: Artist: SNAP!, Genre: house, Year: 1990, Dance: 74 => 0
# Insert: 298
# 94/774: Artist: ZZ Top, Genre: rock, Year: 1973, Dance: 55 => 43
# Insert: 774
# 95/544: Artist: *NSYNC, Genre: boy band, Year: 2000, Dance: 61 => 38
# Insert: 544
# 96/101: Artist: Imagine Dragons, Genre: rock, Year: 2018, Dance: 38 => 26
# Insert: 101
# 97/3: Artist: Stardust, Genre: unknown, Year: 1998, Dance: 73 => 3
# Insert: 3
# 98/750: Artist: The Spencer Davis Group, Genre: rock, Year: 1967, Dance: 55 => 43
# Insert: 750
# 99/535: Artist: Halestorm, Genre: metal, Year: 2012, Dance: 47 => 54
# Insert: 535

# %%
play_list
# Out:
#                         id                                        name  \
# 0   5Q41NLTmGbVPozwHKK7bk2                               Paradise City
# 1   0X1sqQ652p1sceKM2nJlIJ                                     Runaway
# 2   7c1Dar0pIAW7w5TzaGjt9t                                   Jane Says
# 3   33iAwBBb962LFQei4J0b0b                   What Is Love - Single Mix
# 4   33GLigpe5PChdcOz8pGGrq                             One Step Beyond
# 5   2HCaIYjkvWSZzaSKUoOh3d                          Mr. Tambourine Man
# 6   6iWaf45YIhj0YT8GFGxsw0                            Summertime Blues
# 7   2RSHsoi04658QL5xgQVov3                                    Bad Liar
# 8   1CgbwsrNDlFrRuk2ebQ7zr                           9Pm (Till I Come)
# 9   0bRXwKfigvpKZUurwqAlEh                                  Lovely Day
# 10  1yeIxOEFmpQ3qlOb2R3g2m                                  The Ghetto
# 11  2KklXplRtxMsBYo474Es0w                                     Be Mine
# 12  0TqVsIuKYQTNsh1pmAF6Kn                                      Rocker
# 13  3AeQXtVVplbjTX15b9mJyx                 Lockdown (feat. Dave Eggar)
# 14  0E9ZjEAyAwOXZ7wJC0PD33                                  In My Mind
# 15  1ndptsbP6s7WV3fTnp1j74               I'm Not Alone - 2009 Remaster
# 16  7FjZU7XFs7P9jHI9Z0yRhK                                    So Close
# 17  5koBIzuWS86S2IR36yt2LW                               Body Language
# 18  4ZzXPeOfMXk0iKNQGdlzDq  Surf City - Remastered 1990 / Stereo Remix
# 19  3tehrxZR8eaANHov4cEctL                           Smack My Bitch Up
#
#                              artist  year  \
# 0                     Guns N' Roses  1987
# 1                          Bon Jovi  1984
# 2                  Jane's Addiction  1988
# 3                          Haddaway  2011
# 4                           Madness  1979
# 5                         The Byrds  1965
# 6                        Blue Cheer  1990
# 7                   Imagine Dragons  2018
# 8                               ATB  1999
# 9                      Bill Withers  1977
# 10                   Donny Hathaway  1970
# 11                         Ofenbach  2016
# 12                        Alter Ego  2012
# 13                          Amy Lee  2014
# 14          Dynoro, Gigi D'Agostino  2018
# 15                    Calvin Harris  2019
# 16  NOTD, Felix Jaehn, Captain Cuts  2018
# 17          M.A.N.D.Y., Booka Shade  2006
# 18                       Jan & Dean  1990
# 19                      The Prodigy  1997
#
#                                             image_url duration_ms  \
# 0   https://i.scdn.co/image/7fbe9ede6722b20b5f4fe0...      406306
# 1   https://i.scdn.co/image/28b11290613a2789d18910...      230666
# 2   https://i.scdn.co/image/f0f5481643c3e862761c4c...      287000
# 3   https://i.scdn.co/image/cfdd8b9c92638f6951fe5f...      269000
# 4   https://i.scdn.co/image/b27ae22802e8bc51803849...      138373
# 5   https://i.scdn.co/image/48666b9c58218a9d56f9b4...      149466
# 6   https://i.scdn.co/image/d281d4a839c6350eed5a6c...      226906
# 7   https://i.scdn.co/image/9c31900912f3383b769a31...      260773
# 8   https://i.scdn.co/image/d0614396c13068570effa5...      193880
# 9   https://i.scdn.co/image/38340dd280247d4a72d443...      254560
# 10  https://i.scdn.co/image/6ae56879bd303aee1ea3dc...      413773
# 11  https://i.scdn.co/image/5bafe5b8103f931c13c741...      161322
# 12  https://i.scdn.co/image/1f71f6f5e5a5d21c737fe9...      288053
# 13  https://i.scdn.co/image/b31cba60978d6a794d973d...      298613
# 14  https://i.scdn.co/image/5d8f8174d8388619c46a62...      184560
# 15  https://i.scdn.co/image/3c53ca32893f3e56f5694d...      216805
# 16  https://i.scdn.co/image/0b9ac051c0b8d1ac02472d...      190302
# 17  https://i.scdn.co/image/33fa3d1b3e39c7cb664f91...      438013
# 18  https://i.scdn.co/image/4fd80572430b2446045a9d...      163026
# 19  https://i.scdn.co/image/de5d3fad279d8d6f4b1dac...      342733
#
#                                               preview popularity provider  \
# 0                                                 NaN         24  spotify
# 1   https://p.scdn.co/mp3-preview/551134730332e0e2...         67  spotify
# 2   https://p.scdn.co/mp3-preview/2d05da32c80eda03...         63  spotify
# 3                                                 NaN          6  spotify
# 4                                                 NaN          5  spotify
# 5   https://p.scdn.co/mp3-preview/2147c3bcac56bd48...         61  spotify
# 6   https://p.scdn.co/mp3-preview/2bbb00ffebee535c...         37  spotify
# 7   https://p.scdn.co/mp3-preview/fc5f6cf3c0c67f69...         82  spotify
# 8   https://p.scdn.co/mp3-preview/05d17559491d30d2...         61  spotify
# 9   https://p.scdn.co/mp3-preview/300afa67fbdef1d9...         72  spotify
# 10  https://p.scdn.co/mp3-preview/d97329687faa3677...         56  spotify
# 11  https://p.scdn.co/mp3-preview/f99b461583e45414...         70  spotify
# 12                                                NaN          3  spotify
# 13  https://p.scdn.co/mp3-preview/9266b8de4501c792...         36  spotify
# 14  https://p.scdn.co/mp3-preview/93c16bb3fc2389f3...         84  spotify
# 15  https://p.scdn.co/mp3-preview/6582fdd9350eb6b0...         61  spotify
# 16  https://p.scdn.co/mp3-preview/43f9160e3d3cef58...         79  spotify
# 17  https://p.scdn.co/mp3-preview/a7894be7a137b526...         33  spotify
# 18  https://p.scdn.co/mp3-preview/5153e86fc739ba8e...         51  spotify
# 19  https://p.scdn.co/mp3-preview/f5e887b70734de7b...         63  spotify
#
#                                                 genre danceability energy  \
# 0                         glam metal, hard rock, rock           27     95
# 1                                    glam metal, rock           48     90
# 2   alternative metal, alternative rock, blues-roc...           43     65
# 3      bubblegum dance, eurodance, europop, hip house           68     76
# 4                        dance rock, ska, ska revival           47     92
# 5   album rock, art rock, blues-rock, brill buildi...           46     47
# 6   blues-rock, classic garage rock, classic rock,...           46     51
# 7                                   modern rock, rock           38     64
# 8   german dance, german techno, progressive tranc...           67     94
# 9       classic soul, funk, motown, quiet storm, soul           69     65
# 10  chicago soul, classic soul, funk, motown, neo ...           74     52
# 11                   new french touch, tropical house           78     67
# 12                                                NaN           69     47
# 13                                                NaN           52     86
# 14                                edm, tropical house           69     77
# 15  edm, electro house, house, pop, progressive ho...           61     96
# 16  dance pop, edm, electropop, pop, pop edm, post...           70     87
# 17             microhouse, minimal techno, tech house           80     68
# 18  brill building pop, bubblegum pop, doo-wop, fo...           47     65
# 19   big beat, breakbeat, electronic, hardcore techno           61     99
#
#    acousticness instrumentalness liveness happiness  bpm genreSimple  \
# 0             2                1       22        50  100       metal
# 1             0                0       15        67  152       metal
# 2             4                0       13        49   82       metal
# 3             2                1       26        74  124       dance
# 4             5                4       16        94  155        rock
# 5            51                0       44        64  120        rock
# 6            46                0       27        66  138        rock
# 7             7                0       37         8  178        rock
# 8             3               93       15        75  130       dance
# 9            29                0       11        71   98        soul
# 10           37               19       18        83  114        soul
# 11           19                0        6        51  123       house
# 12            0               44        8        56  130     unknown
# 13            1               21       65        10   93     unknown
# 14           18                0       12        16  126         edm
# 15            1                2       21        17  128         edm
# 16           12                0       10        76  125         pop
# 17            1               90        9        87  130      techno
# 18           60                0       34        94  148         pop
# 19            0               59       11        23  136        beat
#
#    genreSimpleNum cluster
# 0              52      45
# 1              52      45
# 2              52      45
# 3              12      22
# 4              62      42
# 5              62      42
# 6              62      33
# 7              62      26
# 8              12       2
# 9              70      47
# 10             70      47
# 11             42      14
# 12              1       5
# 13              1       5
# 14             20      11
# 15             20      11
# 16             54      19
# 17             74       4
# 18             54      36
# 19              3      15
